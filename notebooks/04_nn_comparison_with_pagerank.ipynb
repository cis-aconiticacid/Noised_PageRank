# %% [markdown]
# # 04 nn comparison with pagerank
#
# Compare neural-network trajectories with PageRank baselines via Hilbert metrics.

# %% [markdown]
# # 04 nn comparison with pagerank
#
# Overlay contraction curves for NN, clean, noisy, and thresholded PageRank runs.
