# %% [markdown]
# # 02 threshold and boundary effects
#
# Thresholded PageRank experiments exploring cone-boundary interactions.

# %% [markdown]
# # 02 threshold and boundary effects
#
# Vary the threshold parameter to see when Hilbert distance spikes appear.
