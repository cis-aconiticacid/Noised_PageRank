# %% [markdown]
# # 00 setup and sanity checks
#
# Environment setup and quick sanity checks for Hilbert metric and PageRank.

# %% [markdown]
# # 00 setup and sanity checks
#
# Run the cells to verify imports, compute a tiny Hilbert distance, and confirm a toy Google matrix is well-defined.
