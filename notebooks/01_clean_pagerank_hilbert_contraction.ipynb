# %% [markdown]
# # 01 clean pagerank hilbert contraction
#
# Baseline experiments for deterministic PageRank and Hilbert contraction.

# %% [markdown]
# # 01 clean pagerank hilbert contraction
#
# Simulate trajectories from multiple initial points and plot distance-to-final curves.
