# %% [markdown]
# # 03 noisy pagerank and sgd analogy
#
# Additive-noise PageRank iterations to mirror SGD-like perturbations.

# %% [markdown]
# # 03 noisy pagerank and sgd analogy
#
# Sweep over noise levels and visualize long-run Hilbert distance behavior.
